# %%
import pandas as pd

import numpy as np

# %%
df = pd.read_csv('/Users/khyathireddy/Downloads/near earth objects.csv')
print(type(df))
dfNeo = pd.read_csv('/Users/khyathireddy/Downloads/neo.csv')
dfNeo.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         id                 name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# 3               22.20      False
# 4               20.09       True

# %%
# Merging date column

date_column = df["Close-Approach (CA) Date"].to_list()
dfNeo.drop(dfNeo.index[40000:], inplace=True)
list = date_column + date_column[0:8798]
dfNeo['Close-Approach (CA) Date'] = date_column + date_column [0:8798]
print(df.shape,'\t',dfNeo.shape,'\n',len(list))
print(dfNeo.isna().sum())
dfNeoCSV = dfNeo.to_csv()
dfNeoCSV
print(type(dfNeoCSV))

# %%
dfNew.to_csv (r'/Users/khyathireddy/Downloads/newNeo.csv', index = False, header=True)

# %%
dfNeo.isna().sum()
# Out:
# id                            0
# name                          0
# est_diameter_min              0
# est_diameter_max              0
# orbiting_body                 0
# sentry_object                 0
# hazardous                     0
# miss_distance               202
# relative_velocity           305
# absolute_magnitude          160
# Close-Approach (CA) Date      0
# dtype: int64

# %%
df = pd.read_csv('/Users/khyathireddy/Downloads/near earth objects.csv')
print(type(df))
dfNeo = pd.read_csv('/Users/khyathireddy/Downloads/export_dataframe.csv')
dfNeo.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         id                 name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#   orbiting_body  sentry_object  hazardous      Close-Approach (CA) Date  \
# 0         Earth          False      False  1900-Jan-04 22:25 ±    00:02
# 1         Earth          False       True  1900-Jan-11 01:07 ±    00:18
# 2         Earth          False      False  1900-Jan-12 23:07 ±    00:13
# 3         Earth          False      False  1900-Jan-29 18:13 ±    00:24
# 4         Earth          False       True  1900-Feb-04 03:50 ±    14:49
#
#    miss_distance  relative_velocity  absolute_magnitude
# 0   5.483974e+07       13569.249224               16.73
# 1   6.143813e+07       73588.726663               20.00
# 2   4.979872e+07      114258.692129               17.83
# 3   2.543497e+07       24764.303138               22.20
# 4   4.627557e+07       42737.733765               20.09

# %%
#Formatting Date column
from datetime import datetime

dateList = dfNeo['Close-Approach (CA) Date']

for index in range(len(dateList)):
    dateList[index] = datetime.strptime(dateList[index].split()[0], '%Y-%b-%d').date()

dfNeo = dfNeo.drop('Close-Approach (CA) Date',axis=1)
dfNeo['Close-Approach (CA) Date'] = dateList
dfNeo
# Out:
# /var/folders/dl/n8wnn8kj35s7s9ld46s4r0gr0000gn/T/ipykernel_90155/2050895449.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dateList[index] = datetime.strptime(dateList[index].split()[0], '%Y-%b-%d').date()
#             id                 name  est_diameter_min  est_diameter_max  \
# 0      2162635  162635 (2000 SS164)          1.198271          2.679415
# 1      2277475    277475 (2005 WK4)          0.265800          0.594347
# 2      2512244   512244 (2015 YE18)          0.722030          1.614507
# 3      3596030          (2012 BV13)          0.096506          0.215794
# 4      3667127          (2014 GE35)          0.255009          0.570217
# ...        ...                  ...               ...               ...
# 39995  2487583   487583 (2015 FJ36)          0.096506          0.215794
# 39996  3292262            (2005 TN)          0.088015          0.196807
# 39997  3582523          (2011 UC64)          0.006991          0.015633
# 39998  3607626          (2012 PK24)          0.049723          0.111183
# 39999  3607729           (2012 QD8)          0.063761          0.142574
#
#       orbiting_body  sentry_object  hazardous  miss_distance  \
# 0             Earth          False      False   5.483974e+07
# 1             Earth          False       True   6.143813e+07
# 2             Earth          False      False   4.979872e+07
# 3             Earth          False      False   2.543497e+07
# 4             Earth          False       True   4.627557e+07
# ...             ...            ...        ...            ...
# 39995         Earth          False      False   3.927440e+07
# 39996         Earth          False      False   4.803361e+07
# 39997         Earth          False      False   7.318315e+07
# 39998         Earth          False      False   9.690456e+06
# 39999         Earth          False      False   6.495496e+06
#
#        relative_velocity  absolute_magnitude Close-Approach (CA) Date
# 0           13569.249224               16.73               1900-01-04
# 1           73588.726663               20.00               1900-01-11
# 2          114258.692129               17.83               1900-01-12
# 3           24764.303138               22.20               1900-01-29
# 4           42737.733765               20.09               1900-02-04
# ...                  ...                 ...                      ...
# 39995       31522.477578               22.20               2006-02-15
# 39996       34329.455698               22.40               2006-02-16
# 39997       40139.464355               27.90               2006-02-18
# 39998       37920.870920               23.64               2006-02-22
# 39999       70345.161665               23.10               2006-02-22
#
# [40000 rows x 11 columns]

# %%
dfNeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        40000 non-null  int64
#  1   name                      40000 non-null  object
#  2   est_diameter_min          40000 non-null  float64
#  3   est_diameter_max          40000 non-null  float64
#  4   orbiting_body             40000 non-null  object
#  5   sentry_object             40000 non-null  bool
#  6   hazardous                 40000 non-null  bool
#  7   miss_distance             39798 non-null  float64
#  8   relative_velocity         39695 non-null  float64
#  9   absolute_magnitude        39840 non-null  float64
#  10  Close-Approach (CA) Date  40000 non-null  object
# dtypes: bool(2), float64(5), int64(1), object(3)
# memory usage: 2.8+ MB

# %%
#find count of duplicated terms
print(dfNeo.duplicated().sum())
# Out:
# 0

# %%
#onehotencoding

import sklearn
import sklearn.preprocessing
from sklearn.preprocessing import OneHotEncoder

encoding = OneHotEncoder()
hazardous_array = encoding.fit_transform(dfNeo[["hazardous"]]).toarray()
hazardous_labels = np.array(encoding.categories_).ravel()
dfNew = pd.concat([dfNeo,pd.DataFrame(hazardous_array,columns=hazardous_labels)],axis = 1)
dfNew

# %%
hazardous_array = encoding.fit_transform(dfNeo[["hazardous"]]).toarray()

# %%
hazardous_labels = np.array(encoding.categories_).ravel()
print(hazardous_labels)
# Out:
# [False  True]

# %%
dfNew = pd.concat([dfNeo,pd.DataFrame(hazardous_array,columns=hazardous_labels)],axis = 1)

dfNew
# Out:
#             id                 name  est_diameter_min  est_diameter_max  \
# 0      2162635  162635 (2000 SS164)          1.198271          2.679415
# 1      2277475    277475 (2005 WK4)          0.265800          0.594347
# 2      2512244   512244 (2015 YE18)          0.722030          1.614507
# 3      3596030          (2012 BV13)          0.096506          0.215794
# 4      3667127          (2014 GE35)          0.255009          0.570217
# ...        ...                  ...               ...               ...
# 39995  2487583   487583 (2015 FJ36)          0.096506          0.215794
# 39996  3292262            (2005 TN)          0.088015          0.196807
# 39997  3582523          (2011 UC64)          0.006991          0.015633
# 39998  3607626          (2012 PK24)          0.049723          0.111183
# 39999  3607729           (2012 QD8)          0.063761          0.142574
#
#       orbiting_body  sentry_object  hazardous  miss_distance  \
# 0             Earth          False      False   5.483974e+07
# 1             Earth          False       True   6.143813e+07
# 2             Earth          False      False   4.979872e+07
# 3             Earth          False      False   2.543497e+07
# 4             Earth          False       True   4.627557e+07
# ...             ...            ...        ...            ...
# 39995         Earth          False      False   3.927440e+07
# 39996         Earth          False      False   4.803361e+07
# 39997         Earth          False      False   7.318315e+07
# 39998         Earth          False      False   9.690456e+06
# 39999         Earth          False      False   6.495496e+06
#
#        relative_velocity  absolute_magnitude Close-Approach (CA) Date  False  \
# 0           13569.249224               16.73               1900-01-04    1.0
# 1           73588.726663               20.00               1900-01-11    0.0
# 2          114258.692129               17.83               1900-01-12    1.0
# 3           24764.303138               22.20               1900-01-29    1.0
# 4           42737.733765               20.09               1900-02-04    0.0
# ...                  ...                 ...                      ...    ...
# 39995       31522.477578               22.20               2006-02-15    1.0
# 39996       34329.455698               22.40               2006-02-16    1.0
# 39997       40139.464355               27.90               2006-02-18    1.0
# 39998       37920.870920               23.64               2006-02-22    1.0
# 39999       70345.161665               23.10               2006-02-22    1.0
#
#        True
# 0       0.0
# 1       1.0
# 2       0.0
# 3       0.0
# 4       1.0
# ...     ...
# 39995   0.0
# 39996   0.0
# 39997   0.0
# 39998   0.0
# 39999   0.0
#
# [40000 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid")

categoryList = ['miss_distance','absolute_magnitude']
for category in categoryList:
    sns.catplot(
        data=dfNew, x=category, y="hazardous", kind="box",orient='h', palette="Pastel1"
    )
plt.show()

# %%
sns.violinplot(x ='relative_velocity', y='hazardous',data = dfNew, orient='h')
plt.show()

# %%
dfNew = dfNew.drop('sentry_object', axis=1)
dfNew
# Out:
#             id                 name  est_diameter_min  est_diameter_max  \
# 0      2162635  162635 (2000 SS164)          1.198271          2.679415
# 1      2277475    277475 (2005 WK4)          0.265800          0.594347
# 2      2512244   512244 (2015 YE18)          0.722030          1.614507
# 3      3596030          (2012 BV13)          0.096506          0.215794
# 4      3667127          (2014 GE35)          0.255009          0.570217
# ...        ...                  ...               ...               ...
# 39995  2487583   487583 (2015 FJ36)          0.096506          0.215794
# 39996  3292262            (2005 TN)          0.088015          0.196807
# 39997  3582523          (2011 UC64)          0.006991          0.015633
# 39998  3607626          (2012 PK24)          0.049723          0.111183
# 39999  3607729           (2012 QD8)          0.063761          0.142574
#
#       orbiting_body  hazardous  miss_distance  relative_velocity  \
# 0             Earth      False   5.483974e+07       13569.249224
# 1             Earth       True   6.143813e+07       73588.726663
# 2             Earth      False   4.979872e+07      114258.692129
# 3             Earth      False   2.543497e+07       24764.303138
# 4             Earth       True   4.627557e+07       42737.733765
# ...             ...        ...            ...                ...
# 39995         Earth      False   3.927440e+07       31522.477578
# 39996         Earth      False   4.803361e+07       34329.455698
# 39997         Earth      False   7.318315e+07       40139.464355
# 39998         Earth      False   9.690456e+06       37920.870920
# 39999         Earth      False   6.495496e+06       70345.161665
#
#        absolute_magnitude Close-Approach (CA) Date  False  True rarity
# 0                   16.73               1900-01-04    1.0   0.0      2
# 1                   20.00               1900-01-11    0.0   1.0      1
# 2                   17.83               1900-01-12    1.0   0.0      2
# 3                   22.20               1900-01-29    1.0   0.0      1
# 4                   20.09               1900-02-04    0.0   1.0      1
# ...                   ...                      ...    ...   ...    ...
# 39995               22.20               2006-02-15    1.0   0.0      1
# 39996               22.40               2006-02-16    1.0   0.0      0
# 39997               27.90               2006-02-18    1.0   0.0      0
# 39998               23.64               2006-02-22    1.0   0.0      0
# 39999               23.10               2006-02-22    1.0   0.0      0
#
# [40000 rows x 13 columns]
